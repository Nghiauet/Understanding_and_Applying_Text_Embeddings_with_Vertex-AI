# %%
import vertexai
from vertexai.language_models import CodeChatModel

vertexai.init(project="nghia-experiment-vertex-ai", location="us-central1")
chat_model = CodeChatModel.from_pretrained("codechat-bison@001")
parameters = {
    "candidate_count": 1,
    "max_output_tokens": 1024,
    "temperature": 0.2
}
chat = chat_model.start_chat()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# c:\Users\HP\Documents\WORKSPACE_WINDOW\Learning\Understanding and Applying Text Embeddings with Vertex AI\codechat-bison.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/WORKSPACE_WINDOW/Learning/Understanding%20and%20Applying%20Text%20Embeddings%20with%20Vertex%20AI/codechat-bison.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from vertexai.language_models import CodeChatModel
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Documents/WORKSPACE_WINDOW/Learning/Understanding%20and%20Applying%20Text%20Embeddings%20with%20Vertex%20AI/codechat-bison.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> vertexai.init(project="nghia-experiment-vertex-ai", location="us-central1")
# ...
